# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
! ls
# Out:
#  EpicInstaller-12.1.7-enterprise-3ee675c9552e4d5bb3839a45aae43da3.msi
#  QGroundControl.AppImage
#  ShapeNetCore.v2.zip
#  Untitled.ipynb
#  VNC-Viewer-6.21.406-Linux-x64.deb
#  __MACOSX
#  blender-2.93.1-linux-x64
#  blender-2.93.1-linux-x64.tar.xz
#  camera_trajectory.csv
#  cuda
#  jeju
#  nerf_synthetic
#  nerf_synthetic.zip
#  results_test_200
#  ship.blend
#  teamviewer_15.19.3_amd64.deb
# 'test_00_town05 (1).zip'
#  test_00_town05.zip
#  test_circle_yaw.csv

# %%
import pandas as pd
df = pd.read_csv('/home/cvlab/Desktop/camera_trajectory.csv')

# %%
xs = df[' x'].tolist()
ys = df[' y'].tolist()
zs = df[' z'].tolist()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.plot(xs,ys,zs)

# %%
ax.plot3D(xs, ys, zs)
